# %%
import numpy as np
import filecmp
import pynq.lib.dma
from pynq import Xlnk
import time
from pynq import Overlay
from pynq import MMIO
ol= Overlay("kociemba.bit")

maxDepthBaseAddress = 0x080
unsolvableBaseAddress = 0x088
coloursBaseAddress = 0x040
orderBaseAddress = 0x090
moveArrayBaseAddress = 0x0a0
mmio=MMIO(0x43C00000,0x10000)

mmio.write(maxDepthBaseAddress, 30)
print(mmio.read(maxDepthBaseAddress))

def readfile_short(fileName):
    f = open(fileName,'rb')
    buffer= f.read()
    lSize=f.tell()
    buffer_short = np.fromstring(buffer,dtype=np.short)
    open(cmpFile, 'w').close()
    f_out = open(cmpFile,'w+b')
    f_out.write(buffer_short)
    f.close()
    f_out.close()
    return buffer_short, int(lSize/2)

def readfile_int(fileName):
    f = open(fileName,'rb')
    buffer= f.read()
    lSize=f.tell()
    buffer_int = np.fromstring(buffer,dtype=np.int32)
    open(cmpFile, 'w').close()
    f_out = open(cmpFile,'w+b')
    f_out.write(buffer_int)
    f.close()
    f_out.close()
    return buffer_int, int(lSize/4)

def readfile_char(fileName):
    f = open(fileName,'rb')
    buffer= f.read()
    lSize=f.tell()
    buffer_char = np.fromstring(buffer,dtype=np.byte)
    open(cmpFile, 'w').close()
    f_out = open(cmpFile,'w+b')
    f_out.write(buffer_char)
    f.close()
    f_out.close()
    return buffer_char, lSize
#######################################################################################################################
xlnk = Xlnk()
xlnk.xlnk_reset()

cmpFile = "results/cmp"

list_file_int= ["results/twistMoveInt"]

list_file_short = ["results/twistMove",\
                   "results/flipMove",\
                   "results/FRtoBR_Move",\
#                    "results/FRtoBR_Move",\
                   "results/URFtoDLF_Move",\
                   "results/URtoDF_Move",\
                   "results/URtoUL_Move",\
                   "results/UBtoDF_Move",\
                   "results/MergeURtoULandUBtoDF"]

list_file_char = ["results/Slice_URFtoDLF_Parity_Prun",\
                  "results/Slice_URtoDF_Parity_Prun",\
                  "results/Slice_Twist_Prun",\
                  "results/Slice_Flip_Prun"]

pruneTableMem=[]

###############################################################################################################################
j =0;
# for file in list_file_int:
#     pruneTable, size = readfile_int(file)
#     if (filecmp.cmp(file,cmpFile)==False):
#         print("file compared fail")
#     pruneTableMem.append(xlnk.cma_array(shape=(size,), dtype=np.int32))
#     for i in np.arange(size):
#         pruneTableMem[j][i]=pruneTable[i]
#     j = j + 1
    
for file in list_file_short:
    pruneTable, size = readfile_short(file)
    if (filecmp.cmp(file,cmpFile)==False):
        print("file compared fail")
    pruneTableMem.append(xlnk.cma_array(shape=(size,), dtype=np.short))
    for i in np.arange(size):
        pruneTableMem[j][i]=pruneTable[i]
    j = j + 1
        
for file in list_file_char:
    pruneTable, size = readfile_char(file)
    if (filecmp.cmp(file,cmpFile)==False):
        print("file compared fail")
    pruneTableMem.append(xlnk.cma_array(shape=(size,), dtype=np.byte))
    for i in np.arange(size):
        pruneTableMem[j][i]=pruneTable[i]
    j = j + 1
    
##############################################################################################################################
pruneTable_address=[0x010,0x018,0x020,0x028,0x030,0x038,0x098,0x0c0,0x0c8,0x0d0,0x0d8,0x0e0 ]

for i in np.arange(len(pruneTable_address)):
    mmio.write(pruneTable_address[i],pruneTableMem[i].physical_address)
# Out:
# 30

# %%
moves= []

def assign(mNum):
    if(mNum==0):
        moves.append("U-")
    elif(mNum==1):
        moves.append("U2")
    elif(mNum==2):
        moves.append("U'")
    elif(mNum==3):
        moves.append("R-")
    elif(mNum==4):
        moves.append("R2")
    elif(mNum==5):
        moves.append("R'")
    elif(mNum==6):
        moves.append("F-")
    elif(mNum==7):
        moves.append("F2")
    elif(mNum==8):
        moves.append("F'")
    elif(mNum==9):
        moves.append("D-")
    elif(mNum==10):
        moves.append("D2")
    elif(mNum==11):
        moves.append("D'")
    elif(mNum==12):
        moves.append("L-")
    elif(mNum==13):
        moves.append("L2")
    elif(mNum==14):
        moves.append("L'")
    elif(mNum==15):
        moves.append("B-")
    elif(mNum==16):
        moves.append("B2")
    elif(mNum==17):
        moves.append("B'")
    else:
        print("error in coverting value in memory to move")


def bytes(num):
    assign(num& 0xff) 
    assign(num >>8 & 0xff)
    assign(num >> 16 & 0xff)
    assign(num >> 24& 0xff)

def solve(colours):
#     global tmp
    mmio.write(0x0a0,0)
    for i in np.arange(0,52,4):
        coloursMem = ord(colours[i]) + (ord(colours[i+1])<< 8) + (ord(colours[i+2])<< 16) +(ord(colours[i+3])<< 24)
        mmio.write(coloursBaseAddress+ i ,coloursMem)
    coloursMem= ord(colours[52]) +(ord(colours[53])<< 8)
    mmio.write(coloursBaseAddress+ 52 ,coloursMem)
#     print(mmio.read(0x000))
    mmio.write(0x000, 1)
    start_time = time.time()
    while ((mmio.read(0x000)& 0x2)!=2):
#     while ((mmio.read(0x94))!=1):
#         print(hex(mmio.read(0x0a0)), end = ' ')
        pass
    elapsed_time = time.time() - start_time
    order= int(mmio.read(orderBaseAddress))
    j=0
    moves.clear()
    if (mmio.read(unsolvableBaseAddress)==1):
        print("Unsolvable")
        return
    while( j<order):
        data = mmio.read(int(moveArrayBaseAddress)+j)
        bytes(data)
        j=j+4
    print("Number of moves is ", order)
    print("elapsed time is ", elapsed_time)
    print(moves[0:order])
#     tmp= tmp+elapsed_time
#     print(elapsed_time)

# %%
#kociemba Reduce DMA
solve("DRLUUBFBRBLURRLRUBLRDDFDLFUFUFFDBRDUBRUFLLFDDBFLUBLRBD")
solve("FLBUULFFLFDURRDBUBUUDDFFBRDDBLRDRFLLRLRULFUDRRBDBBBUFL")
solve("BBURUDBFUFFFRRFUUFLULUFUDLRRDBBDBDBLUDDFLLRRBRLLLBRDDF")
solve("UUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBB")
solve("BBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLL")
solve("LLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDD")
solve("DDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFF")
solve("FFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRR")
solve("RRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUU")
# Out:
# Number of moves is  19
# elapsed time is  0.016464948654174805
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# Number of moves is  21
# elapsed time is  0.15746045112609863
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# Number of moves is  21
# elapsed time is  1.0716588497161865
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# Number of moves is  0
# elapsed time is  3.457069396972656e-05
# []
# Number of moves is  0
# elapsed time is  3.314018249511719e-05
# []
# Number of moves is  0
# elapsed time is  3.266334533691406e-05
# []
# Number of moves is  0
# elapsed time is  3.314018249511719e-05
# []
# Number of moves is  0
# elapsed time is  3.314018249511719e-05
# []
# Number of moves is  0
# elapsed time is  3.2901763916015625e-05
# []

# %%
# global tmp
tmp=0
solve ("BBURUDBFUFFFRRFUUFLULUFUDLRRDBBDBDBLUDDFLLRRBRLLLBRDDF")
solve ("FDLUUURLFLBDFRRDLBBBUBFLDDLFBBUDUBRLURDFLRUFRFLRFBDUDR")
solve ("UDRFULDRBLDUBRDUFBFBDRFDFURLBBLDRDURLLRULUFBUFRBFBFDLL")
solve ("LRLLURRLBDUULRFUFLFDRUFBRBLDUFDDRRBDDFURLLBFFBDBUBBFDU")
solve ("UUULULFLFDUBDRRDBBUFLFFLBRRLDFFDDBUUFBRRLDRUDLBLFBBRRD")
solve ("LRRFUUBDLFBBLRDLLRUFDLFURLFBBUBDDDDUDULRLFRRDUUBRBFFBF")
solve ("FBRDULFBRFBBRRRDLBRRUDFUUDFLBLFDUBFDLLDLLFRRBUUUDBFLUD")
solve ("FLBUULFFLFDURRDBUBUUDDFFBRDDBLRDRFLLRLRULFUDRRBDBBBUFL")
solve ("UBLLURBDLDDFRRLRFLDFBLFURFFFLDBDULBUBDRRLBDDUUURUBFBRF")
solve ("UDLFUBLRFRDDLRFDBDBBDDFUUUBFRRLDUFFLBLUFLRRBLFLRUBDBRU")
solve ("URBLUBDDBURDLRDLDBFBLLFFULDBBFUDFLRRRURBLDFFRLUFRBUDFU")
solve ("BLBDUULUDBLRDRFLBUUBLRFFURDLDFRDRRUFRBFLLUFFBDDULBBRFD")
solve ("ULFUUURRURLLLRRUBLDFFLFFBDRURBRDDDFBFBFFLDBBLDBLUBDDUR")
solve ("LUFBUUUDDLLRDRRDDLBFFFFRUDBLLRRDBRBFDURFLRFUBUFBBBLULD")
solve ("UDDBURDDBUFLFRLFDFRRLRFLUBRFDUBDFRFLBLBRLUFULBLRUBBDUD")
solve ("UUBUUBUDBDRLFRFDUDBBRBFRFBRUUFDDLLDFFRRDLLBRRUFLLBFLLD")
solve ("BDLRULLRRDFFBRLDRLBFFFFUUDBBRRLDURDDLBULLUUBRUBDUBDFFF")
solve ("LFRUULBBDBFBDRBLFRDDLLFLFRDRBFDDUBUUURRFLBLRDURFUBDFLU")
solve ("UBBRUDBLFRBRRRUFBBLFDDFFFULUFDDDLBLUFUDBLRLFRDULLBRRDU")
solve ("FRRUUFURDBLFRRFFLUBDLRFBLFUFULLDDBBBULRDLURBDDFRDBBLUD")
solve ("ULDFUBBRRBDLFRBFFLUUDBFLRFDUDRLDUFUDRRLDLUUDBBBFRBRFLL")
solve ("DRUUUDDBRULLBRBFFLLLBFFDBURLFUUDLRRURRFFLDFLDFDBUBRBBD")
# Out:
# Number of moves is  21
# 1.1027319431304932
# Number of moves is  22
# 2.6079232692718506
# Number of moves is  21
# 1.5280215740203857
# Number of moves is  22
# 2.095278024673462
# Number of moves is  20
# 0.9660253524780273
# Number of moves is  20
# 0.05652165412902832
# Number of moves is  21
# 0.4600636959075928
# Number of moves is  21
# 0.15901803970336914
# Number of moves is  22
# 2.0519402027130127
# Number of moves is  20
# 1.5607807636260986
# Number of moves is  21
# 0.9998600482940674
# Number of moves is  21
# 0.47265005111694336
# Number of moves is  22
# 4.873354196548462
# Number of moves is  21
# 2.01116943359375
# Number of moves is  21
# 0.19232654571533203
# Number of moves is  18
# 0.07662010192871094
# Number of moves is  20
# 0.07154488563537598
# Number of moves is  20
# 0.15235328674316406
# Number of moves is  20
# 0.4075615406036377
# Number of moves is  21
# 0.41132211685180664
# Number of moves is  21
# 0.6563727855682373
# Number of moves is  21
# 0.41172242164611816

# %%
print(tmp)
# Out:
# 23.325161933898926

# %%
#kociemba HP dma
solve("DRLUUBFBRBLURRLRUBLRDDFDLFUFUFFDBRDUBRUFLLFDDBFLUBLRBD")
solve("FLBUULFFLFDURRDBUBUUDDFFBRDDBLRDRFLLRLRULFUDRRBDBBBUFL")
solve("BBURUDBFUFFFRRFUUFLULUFUDLRRDBBDBDBLUDDFLLRRBRLLLBRDDF")
solve("UUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBB")
solve("BBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLL")
solve("LLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDD")
solve("DDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFF")
solve("FFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRR")
solve("RRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUU")
# Out:
# 4
# Number of moves is  19
# elapsed time is  0.02464437484741211
# ['D2', "R'", "D'", 'F2', 'B', 'D', 'R2', 'D2', "R'", 'F2', "D'", 'F2', "U'", 'B2', 'L2', 'U2', 'D', 'R2', 'U']
# 4
# Number of moves is  20
# elapsed time is  0.2163083553314209
# ['U2', 'D', "B'", 'U2', "R'", 'D2', 'L2', 'D', 'R2', 'L', "B'", "U'", 'L2', 'D', 'L2', 'D', 'F2', 'L2', 'B2', "U'"]
# 4
# Number of moves is  21
# elapsed time is  1.6356415748596191
# ['B', "U'", "L'", "D'", "R'", "D'", 'L2', "D'", 'L', "F'", "L'", 'D', 'F2', 'R2', 'U', 'R2', 'B2', 'U2', 'L2', 'F2', "D'"]
# 4
# Number of moves is  0
# elapsed time is  3.170967102050781e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.0994415283203125e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.123283386230469e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.147125244140625e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.123283386230469e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.075599670410156e-05
# []

# %%
#No reduce DMA
solve("DRLUUBFBRBLURRLRUBLRDDFDLFUFUFFDBRDUBRUFLLFDDBFLUBLRBD")
solve("FLBUULFFLFDURRDBUBUUDDFFBRDDBLRDRFLLRLRULFUDRRBDBBBUFL")
solve("BBURUDBFUFFFRRFUUFLULUFUDLRRDBBDBDBLUDDFLLRRBRLLLBRDDF")
solve("UUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBB")
solve("BBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLL")
solve("LLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDD")
solve("DDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFF")
solve("FFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRR")
solve("RRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUU")
# Out:
# 4
# Number of moves is  19
# elapsed time is  0.030593395233154297
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  21
# elapsed time is  0.27029895782470703
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  1.895421028137207
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  0
# elapsed time is  3.0517578125e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.0279159545898438e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.218650817871094e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.0994415283203125e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.0994415283203125e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.0279159545898438e-05
# []

# %%
#No concurrent
solve("DRLUUBFBRBLURRLRUBLRDDFDLFUFUFFDBRDUBRUFLLFDDBFLUBLRBD")
solve("FLBUULFFLFDURRDBUBUUDDFFBRDDBLRDRFLLRLRULFUDRRBDBBBUFL")
solve("BBURUDBFUFFFRRFUUFLULUFUDLRRDBBDBDBLUDDFLLRRBRLLLBRDDF")
solve("UUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBB")
solve("BBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLL")
solve("LLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDD")
solve("DDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFF")
solve("FFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRR")
solve("RRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUU")
# Out:
# 4
# Number of moves is  19
# elapsed time is  0.030297040939331055
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  21
# elapsed time is  0.267315149307251
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  1.8838098049163818
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  0
# elapsed time is  3.3855438232421875e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.266334533691406e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.361701965332031e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.3855438232421875e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.337860107421875e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.266334533691406e-05
# []

# %%
#50M
solve("DRLUUBFBRBLURRLRUBLRDDFDLFUFUFFDBRDUBRUFLLFDDBFLUBLRBD")
solve("FLBUULFFLFDURRDBUBUUDDFFBRDDBLRDRFLLRLRULFUDRRBDBBBUFL")
solve("BBURUDBFUFFFRRFUUFLULUFUDLRRDBBDBDBLUDDFLLRRBRLLLBRDDF")
solve("UUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBB")
solve("BBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLL")
solve("LLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDD")
solve("DDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFF")
solve("FFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRR")
solve("RRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUU")
# Out:
# 4
# Number of moves is  19
# elapsed time is  0.01676797866821289
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  21
# elapsed time is  0.1587984561920166
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  1.1022591590881348
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  0
# elapsed time is  3.075599670410156e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.123283386230469e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.147125244140625e-05
# []
# 4
# Number of moves is  0
# elapsed time is  2.9802322387695312e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.075599670410156e-05
# []
# 4
# Number of moves is  0
# elapsed time is  3.0994415283203125e-05
# []

# %%
#100M
# solve("DRLUUBFBRBLURRLRUBLRDDFDLFUFUFFDBRDUBRUFLLFDDBFLUBLRBD")
# solve("FLBUULFFLFDURRDBUBUUDDFFBRDDBLRDRFLLRLRULFUDRRBDBBBUFL")
# solve("BBURUDBFUFFFRRFUUFLULUFUDLRRDBBDBDBLUDDFLLRRBRLLLBRDDF")
# solve("UUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBB")
# solve("BBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLL")
# solve("LLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFFDDDDDDDDD")
# solve("DDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRRFFFFFFFFF")
# solve("FFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUURRRRRRRRR")
# solve("RRRRRRRRRFFFFFFFFFDDDDDDDDDLLLLLLLLLBBBBBBBBBUUUUUUUUU")

solve ("DRLUUBFBRBLURRLRUBLRDDFDLFUFUFFDBRDUBRUFLLFDDBFLUBLRBD") 
solve ("FLBUULFFLFDURRDBUBUUDDFFBRDDBLRDRFLLRLRULFUDRRBDBBBUFL")
solve ("BBURUDBFUFFFRRFUUFLULUFUDLRRDBBDBDBLUDDFLLRRBRLLLBRDDF")
solve ("LLLBUBLLLBRBURUBRBUUUFFFUUURRRFDFRRRFLFDLDFLFDDDBBBDDD")
solve ("UFLFUBFRLBDBBRLFBRRUUFFUDBURLLDDRFLUBRDDLULRBDDRUBLFFD")
solve ("FRRLUBUUBUDURRLLBBBLLUFBRRFDFUDDUDURDBRFLRLFFFDLDBLDFB")
solve ("DBDRULDUBLBFDRRULFFBDLFRUDFBFRBDFULURURULUBRRLDBFBFLDL")
# Out:
# 4
# Number of moves is  19
# elapsed time is  0.01681208610534668
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  21
# elapsed time is  0.15883684158325195
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  1.098879098892212
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  12
# elapsed time is  0.003442049026489258
# ["U'", 'D2', 'D', 'U2', 'R', 'R2', 'L2', 'L', "L'", 'L', 'L2', 'R']
# 4
# Number of moves is  21
# elapsed time is  1.321582317352295
# ['B2', 'D', "U'", 'U', 'L', 'D2', 'L', 'B2', 'U', "D'", 'D', 'R2', "B'", "R'", 'F', 'R2', 'L2', "D'", 'R2', "R'", "L'"]
# 4
# Number of moves is  21
# elapsed time is  0.7229785919189453
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.12755584716796875
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]

# %%
for i in np.arange(20):
    solve("DRLUUBFBRBLURRLRUBLRDDFDLFUFUFFDBRDUBRUFLLFDDBFLUBLRBD")
# Out:
# 4
# Number of moves is  19
# elapsed time is  0.01687908172607422
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.01691412925720215
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.01673436164855957
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.0167238712310791
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.016722440719604492
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.016727209091186523
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.016721248626708984
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.016716957092285156
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.01673722267150879
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.01673293113708496
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.016754865646362305
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.01673126220703125
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.016846895217895508
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.016728878021240234
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.01673150062561035
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.016731739044189453
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.016719341278076172
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.016725540161132812
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.01672530174255371
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']
# 4
# Number of moves is  19
# elapsed time is  0.016722917556762695
# ["L'", 'B', "B'", "R'", 'D2', "D'", 'L', "L'", 'B', "R'", "B'", "R'", 'F', 'L2', 'R2', 'R', "D'", 'L', 'U']

# %%
for i in np.arange(20):
    solve("FLBUULFFLFDURRDBUBUUDDFFBRDDBLRDRFLLRLRULFUDRRBDBBBUFL")
# Out:
# 4
# Number of moves is  21
# elapsed time is  0.15900564193725586
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.1589665412902832
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15878891944885254
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15900969505310059
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.1587514877319336
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15894603729248047
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15877914428710938
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15895700454711914
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15876507759094238
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15905308723449707
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15875768661499023
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15894675254821777
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15879535675048828
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15895819664001465
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15880084037780762
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15898394584655762
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.1587998867034912
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15895795822143555
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15882635116577148
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]
# 4
# Number of moves is  21
# elapsed time is  0.15896248817443848
# ['R', "D'", 'B2', 'R', 'B', "L'", 'R2', "D'", 'L', 'U2', 'B2', 'F', 'R2', "D'", 'R2', 'U', 'R2', 'L2', 'L', 'R', "D'"]

# %%
for i in np.arange(20):
    solve("BBURUDBFUFFFRRFUUFLULUFUDLRRDBBDBDBLUDDFLLRRBRLLLBRDDF")
# Out:
# 4
# Number of moves is  21
# elapsed time is  1.0990803241729736
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0988645553588867
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0988390445709229
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0988454818725586
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0988147258758545
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.1024384498596191
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.09879732131958
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0987629890441895
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0988247394561768
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0988540649414062
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0989000797271729
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0988571643829346
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0987522602081299
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0988154411315918
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0989148616790771
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0988237857818604
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0988171100616455
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.1023285388946533
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.098855972290039
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  1.0988926887512207
# ['D2', 'F', 'F2', "B'", 'B', "B'", 'R2', "B'", 'U2', "F'", 'F2', "D'", "R'", 'L', 'U', 'L', 'L2', 'R', 'R2', "R'", "B'"]

# %%
ol= Overlay("kociemba100M.bit")

mmio=MMIO(0x43C00000,0x10000)

# %%
mmio.read(0x000)
# Out:
# 4

# %%
colours="BBURUDBFUFFFRRFUUFLULUFUDLRRDBBDBDBLUDDFLLRRBRLLLBRDDF"
for i in np.arange(0,52,4):
    coloursMem = ord(colours[i]) + (ord(colours[i+1])<< 8) + (ord(colours[i+2])<< 16) +(ord(colours[i+3])<< 24)
    mmio.write(coloursBaseAddress+ i ,coloursMem)
coloursMem= ord(colours[52]) +(ord(colours[53])<< 8)
mmio.write(coloursBaseAddress+ 52 ,coloursMem)

# %%
for i in np.arange(20):
    solve("FRRLUBUUBUDURRLLBBBLLUFBRRFDFUDDUDURDBRFLRLFFFDLDBLDFB")
    solve("DBDRULDUBLBFDRRULFFBDLFRUDFBFRBDFULURURULUBRRLDBFBFLDL")
# Out:
# 4
# Number of moves is  21
# elapsed time is  2.332616090774536
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.2530386447906494
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.3388113975524902
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.25388145446777344
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.352130174636841
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.25301551818847656
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.331674098968506
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.2530062198638916
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.332218885421753
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.25310564041137695
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.331167459487915
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.25301527976989746
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.3328614234924316
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.25936293601989746
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.3440303802490234
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.2529294490814209
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.332327365875244
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.25333261489868164
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.3306939601898193
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.2531747817993164
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.331057071685791
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.25292253494262695
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.355443239212036
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.2529909610748291
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.3321635723114014
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.25315284729003906
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.337634325027466
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.253023624420166
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.3341727256774902
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.2531421184539795
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.3338959217071533
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.2531168460845947
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.36508846282959
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.2534608840942383
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.3302996158599854
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.25303101539611816
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.3329010009765625
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.25297093391418457
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
# 4
# Number of moves is  21
# elapsed time is  2.3313186168670654
# ['B', 'F', "R'", 'R2', 'U', 'D', 'L2', 'L', 'F2', 'F', "F'", 'U', "R'", "L'", 'L2', "B'", 'R2', 'F', "B'", "R'", 'L']
# 4
# Number of moves is  20
# elapsed time is  0.25323057174682617
# ['F2', "U'", 'L2', 'B', 'D2', 'B', 'U2', 'D2', "B'", "F'", 'U', 'L2', 'U', "R'", "B'", 'R2', 'L', 'U', "R'", "B'"]
